# %% [markdown]
# # Consumo de agua CDMX

# %% [markdown]
# ## Parameters

# %%
BASE_DIR = '/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data'
RESOURCE_ID = '5d33f9c7-e033-4676-a02d-9e2129017acf'
FILE_NAME = 'afluencia_transporte'

# %% [markdown]
# ## Class

# %%
from mariachis.models import AfluenciaTransporte

at = AfluenciaTransporte(BASE_DIR)
print(at)
# Out:
# Directorio:	/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data

# %% [markdown]
# ## Data Wrangling

# %%
df = at.full_import(api=True, resource_id=RESOURCE_ID, api_export=True, export_kwargs={'file_name':FILE_NAME, 'index':False})
df.sample()
# Out:
#           organismo        linea_servicio      dia                fecha  \
# 16497  STE-Trolebús  L7 Lomas Estrella-CU  Viernes  2020-12-25T00:00:00
#
#       afluencia_tarjeta afluencia_boleto afluencia_total_preliminar
# 16497                                                         3,415

# %%
X, y = at.wrangling_afluencia(df, file_name=FILE_NAME, id_cols=['organismo'], aggfunc={'afluencia_total_preliminar':'sum'})
X.head()
# Out:
#                       afluencia_total_preliminar_01  \
# organismo fecha
# Ecobici   2020-03-22                         6760.0
#           2020-03-23                         5770.0
#           2020-03-24                        11697.0
#           2020-03-25                        11358.0
#           2020-03-26                        10541.0
#
#                       afluencia_total_preliminar_02  \
# organismo fecha
# Ecobici   2020-03-22                        16091.0
#           2020-03-23                         6760.0
#           2020-03-24                         5770.0
#           2020-03-25                        11697.0
#           2020-03-26                        11358.0
#
#                       afluencia_total_preliminar_03  \
# organismo fecha
# Ecobici   2020-03-22                        16676.0
#           2020-03-23                        16091.0
#           2020-03-24                         6760.0
#           2020-03-25                         5770.0
# ...

# %% [markdown]
# ## Model

# %%
model, coef = at.train_reg_model(X,y)
# Out:
# ['Score: 98.96%', 'Training score: 97.80%', 'Estas son las variables más relevantes:']

# %%
coef.head(5).append(coef.tail(5))
# Out:
#                                 0              1
# 0   afluencia_total_preliminar_01  210085.291129
# 1   afluencia_total_preliminar_07  202403.345118
# 2   afluencia_total_preliminar_14   88794.399523
# 3   afluencia_total_preliminar_05   56967.381288
# 4   afluencia_total_preliminar_21   50041.520901
# 16  afluencia_total_preliminar_20  -20368.624232
# 17  afluencia_total_preliminar_19  -28780.920217
# 18  afluencia_total_preliminar_09  -29293.858803
# 19  afluencia_total_preliminar_08  -74164.360229
# 20  afluencia_total_preliminar_15 -119456.041376

# %% [markdown]
# ## Results

# %%
at.plot_real_vs_est(X, y, model, id_col='organismo', from_year=2019)
# Out:
# <div>                            <div id="666aff63-141f-4d90-a0da-1d072f01536f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
