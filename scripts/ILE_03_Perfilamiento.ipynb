# %% [markdown]
# # Perfilamiento

# %% [markdown]
# ## Parámetros

# %%
BASE_DIR = '/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data' # Mac
# BASE_DIR = r'D:\Users\efras\Documents\EF\Contests\Datathon_CDMX\data' # Windows
FILE_NAME = 'interrupcion_embarazo_clean_cluster'

# %% [markdown]
# ## Importar

# %% [markdown]
# ### Entorno

# %%
from pandas import DataFrame
from string import ascii_uppercase

# %% [markdown]
# ### Clase

# %%
from mariachis.interrupcion_embarazo import InterrupcionEmbarazo

ile = InterrupcionEmbarazo(BASE_DIR, FILE_NAME)
print(ile)
# Out:
# Directorio: 	/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data

# %% [markdown]
# ### Datos

# %%
df = ile.full_import(api=False)
df.sample()
# Out:
# Archivo con nombre interrupcion_embarazo_clean_cluster.csv fue encontrado en /Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data
# Con 79383 renglones y 70 columnas
#           año      mes    fingreso autoref edocivil_descripcion  edad  \
# 77354  2017.0  FEBRERO  2017-02-03      SI              SOLTERX  21.0
#
#       desc_derechohab   nivel_edu ocupacion religion  ... rango_gesta  \
# 77354     DESCONOCIDO  SECUNDARIA  EMPLEADX       SI  ...          00
#
#        rango_c_num rango_p_semgest rango_p_diasgesta rango_fsexual_vs_menarca  \
# 77354  DESCONOCIDO         01 a 05       DESCONOCIDO              DESCONOCIDO
#
#       rango_edad_vs_menarca rango_edad_vs_fsexual antes_vs_despues  \
# 77354               09 a 12           DESCONOCIDO            IGUAL
#
#                        antes_vs_despues_detalle cluster
# 77354  antes: DESCONOCIDO, después: DESCONOCIDO       A
#
# [1 rows x 70 columns]

# %% [markdown]
# ### Columnas de clustering

# %%
cluster_cols = ['antes_vs_despues', 'antes_vs_despues_detalle', 'anticonceptivo', 'autoref', 'c_dolor', 'cconsejo', 'consejeria', 'desc_derechohab', 'desc_servicio', 'edad_vs_fsexual', 'edad_vs_menarca', 'edocivil_descripcion', 'fsexual_vs_menarca', 'motiles', 'naborto', 'ncesarea', 'nile', 'nivel_edu', 'npartos', 'ocupacion', 'p_consent', 'panticoncep', 'parentesco', 'procile_completa', 'procile_simplificada', 'rango_c_num', 'rango_edad', 'rango_fsexual', 'rango_gesta', 'rango_menarca', 'rango_nhijos', 'rango_p_diasgesta', 'rango_p_semgest', 'rango_sememb', 'religion', 'resultado_ile', 's_complica', 'tanalgesico']

df[cluster_cols].sample()
# Out:
#       antes_vs_despues           antes_vs_despues_detalle anticonceptivo  \
# 33123        DIFERENTE  antes: NINGUNO, después: IMPLANTE        NINGUNO
#
#            autoref c_dolor cconsejo consejeria desc_derechohab desc_servicio  \
# 33123  DESCONOCIDO      NO       SI         SI     DESCONOCIDO           ILE
#
#       edad_vs_fsexual  ... rango_gesta rango_menarca rango_nhijos  \
# 33123             9.0  ...          01            12  DESCONOCIDO
#
#       rango_p_diasgesta rango_p_semgest rango_sememb religion resultado_ile  \
# 33123                02              06      04 a 06  NINGUNA   DESCONOCIDO
#
#       s_complica tanalgesico
# 33123         NO          NO
#
# [1 rows x 38 columns]

# %% [markdown]
# ## Perfilamiento

# %% [markdown]
# ### Columnas adicionales

# %%
# No se usaron para clustering pero es interesante revisar su distribución por clúster
add_cols = ['fingreso_yearquarter','entidad']

# %% [markdown]
# ### Auxiliar para llenar la interpretación de cada clúster por variable

# %%
# Imprime el diccionario para llenar
aux = df[add_cols+cluster_cols+['cluster']].copy()
{x:{y:'' for y in ascii_uppercase[:len(set(df['cluster']))]} for x in aux.columns}
# Out:
# {'fingreso_yearquarter': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'entidad': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'antes_vs_despues': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'antes_vs_despues_detalle': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'anticonceptivo': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'autoref': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
#   'H': '',
#   'I': '',
#   'J': ''},
#  'c_dolor': {'A': '',
#   'B': '',
#   'C': '',
#   'D': '',
#   'E': '',
#   'F': '',
#   'G': '',
# ...

# %% [markdown]
# ### Recuento

# %%
# Despliega 3 tablas por variable:
#   - Cantidad de registros por cluster (renglones) y clases de la variable (columnas)
#      con formato condicional por columnas (azul oscuro a valores altos, blanco a valores bajos)
#   - Cantidad de registros por clases de la variable (renglones) y cluster (columnas)
#      con formato condicional por columnas (azul oscuro a valores altos, blanco a valores bajos)
#   - Porcentaje de registros respecto al total por cluster (renglones) y clases de la variable (columnas)
#      con formato condicional de toda la tabla (azul oscuro a valores altos, blanco a valores bajos)

ile.profiles(df[add_cols+cluster_cols+['cluster']])
# Out:
# /Users/efraflores/Desktop/hub/dataton_cdmx/scripts/mariachis/base.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['n'] = 1
# <style type="text/css">
# ...

# %% [markdown]
# ### Interpretación

# %%
# El siguiente es un diccionario de diccionarios, el primer nivel es el nombre de la columna,
#   el segundo es el nombre genérico del clúster y el valor que tiene asignado es la 
#   interpretación univariable dadas las 3 tablas por variables desplegadas en la sección anterior

cluster_caract = {
  'fingreso_yearquarter': {
    'A': 'Fuerte en 2016',
    'B': 'Fuerte en 2018',
    'C': '',
    'D': '',
    'E': '',
    'F': 'Fuerte en 2020',
    'G': 'Año DESCONOCIDO',
    'H': 'Fuerte en 2017',
    'I': '',
    'J': 'Fuerte en 2019',
  },
 'entidad': {
    'A': 'Muy alta frec capitalina y EdoMéx',
    'B': 'Alta frec foránea',
    'C': '',
    'D': '',
    'E': 'Muy baja frec capitalina',
    'F': '',
    'G': 'Muy baja frec mexiquense',
    'H': 'Muy alta frec mexiquense',
    'I': '',
    'J': 'Muy baja frec capitalina',
  },
 'antes_vs_despues': {
    'A': 'De quienes mantienen el método, hay más aquí',
    'B': 'De quienes cambian el método, hay más aquí',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'antes_vs_despues_detalle': {
    'A': 'Antes condón y después no especifican',
    'B': 'Antes ninguno y después implante',
    'C': 'No cambian el condón',
    'D': 'Antes ninguno y después no especifican',
    'E': 'Antes ninguno y después no especifican',
    'F': 'Antes ninguno y después no especifican',
    'G': 'Antes ninguno y después no especifican',
    'H': 'Antes ninguno y después implante',
    'I': 'Antes condón y después no especifican',
    'J': 'Antes ninguno y después condón',
  },
 'anticonceptivo': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'autoref': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': 'Acude directamente',
    'H': '',
    'I': 'Referida de otra unidad',
    'J': '',
  },
 'c_dolor': {
    'A': '',
    'B': '',
    'C': 'Dolor después del proced',
    'D': '',
    'E': 'Sin dolor después del proced',
    'F': 'Sin dolor después del proced',
    'G': 'Sin dolor después del proced',
    'H': '',
    'I': 'Dolor después del proced',
    'J': 'Sin dolor después del proced',
  },
 'cconsejo': {
    'A': '',
    'B': '',
    'C': 'Con consejo',
    'D': '',
    'E': '',
    'F': 'Con consejo',
    'G': 'Con consejo',
    'H': '',
    'I': 'Con consejo',
    'J': 'Con consejo',
  },
 'consejeria': {
    'A': 'De quienes no recibieron consejería, la mayoría está aquí',
    'B': 'Recibieron consejería',
    'C': '',
    'D': '',
    'E': '',
    'F': 'Recibieron consejería',
    'G': '',
    'H': 'Recibieron consejería',
    'I': '',
    'J': '',
  },
 'desc_derechohab': {
    'A': 'De quienes tienen seguro, la mayoría está aquí',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': 'No se sabe si tienen seguro',
    'H': 'De quienes NO tienen seguro, la mayoría está aquí',
    'I': 'No se sabe si tienen seguro',
    'J': '',
  },
 'desc_servicio': {
    'A': 'Servicio ILE',
    'B': 'Servicio ILE',
    'C': 'De quienes asistieron al servicio de cirugía ambulatoria, la mayoría está aquí',
    'D': '',
    'E': '',
    'F': '',
    'G': 'Atendidxs por especialidad de ginecología',
    'H': 'Servicio ILE',
    'I': 'Servicios variados en donde se otorga el proced',
    'J': '',
  },
 'edad_vs_fsexual': {
    'A': 'No hay información de su IVSA',
    'B': 'La ILE ocurre a los 4 años después de su IVSA',
    'C': 'La ILE ocurre a los 7 años después de su IVSA',
    'D': 'La ILE ocurre a los 8 años después de su IVSA',
    'E': 'La ILE ocurre a los 8 años después de su IVSA',
    'F': 'La ILE ocurre a los 6 años después de su IVSA',
    'G': 'La ILE ocurre a los 3 años después de su IVSA',
    'H': 'La ILE ocurre a los 4 años después de su IVSA',
    'I': 'La ILE ocurre más de 10 años después de su IVSA',
    'J': 'Muy probablemente la ILE ocurre en su primer encuentro sexual',
  },
 'edad_vs_menarca': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'edocivil_descripcion': {
    'A': 'De quienes están casadxs, la mayoría está aquí',
    'B': 'De quienes están solterxs, la mayoría está aquí',
    'C': 'Unión libre',
    'D': '',
    'E': '',
    'F': 'De quienes están separadxs, la mayoría está aquí',
    'G': '',
    'H': '',
    'I': 'Unión libre',
    'J': '',
  },
 'fsexual_vs_menarca': {
    'A': 'No hay información de su IVSA o de su menarca',
    'B': 'IVSA a los 3 años post-menarca',
    'C': 'IVSA a los 6 años post-menarca',
    'D': 'IVSA a los 4 años post-menarca',
    'E': 'IVSA a los 5 años post-menarca',
    'F': 'IVSA a los 3 años post-menarca',
    'G': 'IVSA a los 3 años post-menarca',
    'H': 'IVSA a los 3 años post-menarca',
    'I': 'IVSA a los 3 años post-menarca',
    'J': 'IVSA a los 5 años post-menarca',
  },
 'motiles': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'naborto': {
    'A': 'Se desconoce si ha tenido aborto',
    'B': 'De quienes no han tenido abortos, la mayoría está aquí',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': 'De quienes no han tenido abortos, la mayoría está aquí',
    'I': 'De quienes han tenido aborto(s), la mayoría está aquí',
    'J': '',
  },
 'ncesarea': {
    'A': 'Se desconoce si ha tenido cesárea',
    'B': 'De quienes no han tenido cesáreas, la mayoría está',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': 'De quienes han tenido cesárea(s), la mayoría está aquí',
    'J': '',
  },
 'nile': {
    'A': 'Se desconoce si ha tenido interrupciones leagales del embarazo',
    'B': 'De quienes no han tenido ILE, la mayoría está',
    'C': '',
    'D': '',
    'E': '',
    'F': 'De quienes han tenido ILE, la mayoría está aquí',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'nivel_edu': {
    'A': 'De quienes tienen máximo primaria o sin acceso a la educación, la mayoría está aquí',
    'B': 'De quienes tienen máximo preparatoria o licenciatura, la mayoría está aquí',
    'C': 'Preparatoria',
    'D': 'Secundaria',
    'E': 'Secundaria',
    'F': 'Varios niveles educativos, pocas personas sin acceso',
    'G': 'De quienes se desconoce el nivel educativo, la mayoría está aquí',
    'H': 'De quienes tienen máximo licenciatura o posgrado, la mayoría está aquí',
    'I': 'Secundaria',
    'J': 'Preparatoria',
  },
 'npartos': {
    'A': 'O no se conoce o ha tenido un parto o más',
    'B': 'No ha tenido partos',
    'C': 'Sí ha tenido partos',
    'D': 'No ha tenido partos',
    'E': 'Sí ha tenido partos',
    'F': 'No ha tenido partos',
    'G': 'No ha tenido partos',
    'H': 'No ha tenido partos',
    'I': 'Mixto en haber tenido o no partos',
    'J': 'Sí ha tenido partos',
  },
 'ocupacion': {
    'A': 'Empleadx',
    'B': 'Se desconoce ocupación o es estudiante',
    'C': 'Trabajadorx del hogar no remuneradx',
    'D': 'Trabajadorx del hogar no remuneradx',
    'E': 'Trabajadorx del hogar no remuneradx',
    'F': 'De quienes están desempleadxs, la mayoría está aquí',
    'G': 'Estudiante y empleadx',
    'H': 'Empleadx',
    'I': 'Trabajadorx del hogar no remuneradx',
    'J': 'Estudiante',
  },
 'p_consent': {
    'A': 'De quienes no firmaron o no se sabe si se requisitó y firmó el consentimiento informado',
    'B': 'No se sabe si se requisitó y firmó el consentimiento informado',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': 'Se requisitó y firmó el consentimiento informado',
    'J': '',
  },
 'panticoncep': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'parentesco': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': 'Llegan acompañadxs',
    'H': '',
    'I': 'Pareja',
    'J': '',
  },
 'procile_completa': {
    'A': 'Terapia dual',
    'B': 'Terapia dual',
    'C': '',
    'D': 'Terapia dual',
    'E': 'Terapia dual',
    'F': '',
    'G': '',
    'H': 'Terapia dual',
    'I': 'Sólo requieren inducción de maduración cervical',
    'J': '',
  },
 'procile_simplificada': {
    'A': 'De quienes usaron medicamento en su procedimiento, la mayoría está aquí',
    'B': '',
    'C': 'De quienes tuvieron procedimiento AMEU, la mayoría está aquí',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': 'De quienes usaron medicamento en su procedimiento, la mayoría está aquí',
    'I': '',
    'J': '',
  },
 'rango_c_num': {
    'A': 'Una cita, dos citas o no se sabe',
    'B': 'Dos citas previas',
    'C': 'Sin citas previas o 2 citas previas',
    'D': 'Una cita previa',
    'E': 'Una cita previa',
    'F': 'No se sabe cuántas citas previas',
    'G': 'A lo más una cita previa',
    'H': 'No se sabe cuántas citas previas',
    'I': 'Tres o más citas previas',
    'J': 'Dos citas previas',
  },
 'rango_edad': {
    'A': '19-35 años mayor frec 26-29',
    'B': '19-25 años mayor frec 19-21',
    'C': '22-29 años',
    'D': '22-25 años',
    'E': '22-35 años frec 22-25',
    'F': '19-35 años mayor frec 22-25',
    'G': '19-29 años',
    'H': '19-25 años mayor frec 22-25',
    'I': '22-35 años mayor frec 30-35',
    'J': '19-21 años',
  },
 'rango_fsexual': {
    'A': 'De quienes tuvieron su IVSA menor a 8 años, la mayoría está aquí',
    'B': 'IVSA 08-15 años',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': 'IVSA 08-11 y >= 19',
    'I': '',
    'J': '',
  },
 'rango_gesta': {
    'A': '2 o más gesta',
    'B': '1 gesta',
    'C': '2 gesta',
    'D': '1 gesta',
    'E': '3 gesta',
    'F': '1-3 gesta',
    'G': '1-2 gesta',
    'H': '1-2 gesta',
    'I': '2-3 gesta',
    'J': '1 gesta',
  },
 'rango_menarca': {
    'A': 'menarca a los 12 años',
    'B': 'menarca de 8-12 años',
    'C': 'menarca de 8-11 años',
    'D': 'menarca a los 13 años',
    'E': 'menarca de 8-11 años',
    'F': 'menarca de 12 años',
    'G': 'menarca de 12 años',
    'H': 'menarca de 8-14 años',
    'I': 'menarca de 12 años',
    'J': 'menarca de 12 años',
  },
 'rango_nhijos': {
    'A': '1 hijx',
    'B': 'Sin hijxs',
    'C': '1 hijx',
    'D': 'Sin hijxs',
    'E': '2 hijxs',
    'F': 'O no tiene o se desconoce número de hijxs',
    'G': 'Sin hijxs',
    'H': 'Sin hijxs',
    'I': '1 o más hijxs',
    'J': 'Sin hijxs',
  },
 'rango_p_diasgesta': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'rango_p_semgest': {
    'A': '7 semanas de gesta',
    'B': '',
    'C': '10 semanas de gesta o más',
    'D': '',
    'E': '7 semanas de gesta',
    'F': '',
    'G': '6-8 semanas de gesta',
    'H': '',
    'I': '6-8 semanas de gesta',
    'J': '7 semanas de gesta',
  },
 'rango_sememb': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': '',
    'G': '',
    'H': '',
    'I': '',
    'J': '',
  },
 'religion': {
    'A': '',
    'B': '',
    'C': '',
    'D': '',
    'E': '',
    'F': 'De quienes respondieron no tener religión, la mayoría está aquí',
    'G': '',
    'H': '',
    'I': '',
    'J': 'De quienes no se sabe si tienen religión, la mayoría está aquí',
  },
 'resultado_ile': {
    'A': 'De quienes respondieron "Otro" el procedimiento ILE, la mayoría está aquí',
    'B': 'De quienes completaron el procedimiento ILE, la mayoría está aquí',
    'C': '',
    'D': '',
    'E': '',
    'F': 'De quienes no se sabe completitud del procedimiento ILE, la mayoría está aquí',
    'G': '',
    'H': '',
    'I': 'De quienes no se sabe completitud del procedimiento ILE, la mayoría está aquí',
    'J': '',
  },
 's_complica': {
    'A': 'Se desconoce si hubo complicaciones en el procedimiento',
    'B': 'Se desconoce si hubo complicaciones en el procedimiento',
    'C': '',
    'D': 'Se desconoce si hubo complicaciones en el procedimiento',
    'E': 'Se desconoce si hubo complicaciones en el procedimiento',
    'F': 'De los procedimientos que no se complican, la mayoría está aquí',
    'G': '',
    'H': 'De los procedimientos que no se complican, la mayoría está aquí',
    'I': '',
    'J': 'De los procedimientos que se complican, la mayoría está aquí',
  },
 'tanalgesico': {
    'A': '',
    'B': 'Se prescribe analgésico',
    'C': 'Se prescribe analgésico',
    'D': '',
    'E': 'No se prescribe analgésico',
    'F': 'No se prescribe analgésico',
    'G': 'No se prescribe analgésico',
    'H': '',
    'I': 'Se prescribe analgésico',
    'J': 'No se prescribe analgésico',
  },
 'cluster': {
    'A': '13.0%',
    'B': '13.4%',
    'C': '08.7%',
    'D': '10.5%',
    'E': '06.1%',
    'F': '12.1%',
    'G': '08.1%',
    'H': '13.1%',
    'I': '08.5%',
    'J': '06.5%',
}}

# %% [markdown]
# ### Compilación

# %%
# De diccionario a tabla de dimensión N_CLUSTERS x VARIABLES
comp = DataFrame(cluster_caract)
comp.sample()
# Out:
#   fingreso_yearquarter entidad antes_vs_despues  \
# F       Fuerte en 2020
#
#                  antes_vs_despues_detalle anticonceptivo autoref  \
# F  Antes ninguno y después no especifican
#
#                         c_dolor     cconsejo             consejeria  \
# F  Sin dolor después del proced  Con consejo  Recibieron consejería
#
#   desc_derechohab  ...       rango_menarca  \
# F                  ...  menarca de 12 años
#
#                                 rango_nhijos rango_p_diasgesta  \
# F  O no tiene o se desconoce número de hijxs
#
#   rango_p_semgest rango_sememb  \
# F
#
#                                             religion  \
# F  De quienes respondieron no tener religión, la ...
#
#                                        resultado_ile  \
# F  De quienes no se sabe completitud del procedim...
#
#                                           s_complica  \
# F  De los procedimientos que no se complican, la ...
#
#                   tanalgesico cluster
# ...

# %%
# Unir la interpretación de todas las variables contempladas
comp['total'] = comp.apply(lambda x: ' - '.join(x), axis=1)
comp[['total']].T.to_dict()
# Out:
# {'A': {'total': 'Fuerte en 2016 - Muy alta frec capitalina y EdoMéx - De quienes mantienen el método, hay más aquí - Antes condón y después no especifican -  -  -  -  - De quienes no recibieron consejería, la mayoría está aquí - De quienes tienen seguro, la mayoría está aquí - Servicio ILE - No hay información de su IVSA -  - De quienes están casadxs, la mayoría está aquí - No hay información de su IVSA o de su menarca -  - Se desconoce si ha tenido aborto - Se desconoce si ha tenido cesárea - Se desconoce si ha tenido interrupciones leagales del embarazo - De quienes tienen máximo primaria o sin acceso a la educación, la mayoría está aquí - O no se conoce o ha tenido un parto o más - Empleadx - De quienes no firmaron o no se sabe si se requisitó y firmó el consentimiento informado -  -  - Terapia dual - De quienes usaron medicamento en su procedimiento, la mayoría está aquí - Una cita, dos citas o no se sabe - 19-35 años mayor frec 26-29 - De quienes tuvieron su IVSA menor a 8 años,
# ...

# %% [markdown]
# ### Nombramiento

# %% [markdown]
# #### Auxiliar para nombramiento de clústeres

# %%
# Imprime el diccionario vacío para asignar un nombre y otras características a cada clúster

{x:{y:'' for y in ['nombre', 'conclusion_general', 'caracteristicas_de_minorias']} for x in ascii_uppercase[:len(set(df['cluster']))]}
# Out:
# {'A': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'B': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'C': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'D': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'E': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'F': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'G': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'H': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'I': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''},
#  'J': {'nombre': '',
#   'conclusion_general': '',
#   'caracteristicas_de_minorias': ''}}

# %% [markdown]
# #### De diccionario ...

# %%
nom = {
    'A': {
        'nombre':'Educación restringida e Inicio de Vida Sexual Activa (IVSA) temprana',
        'conclusión general':'Gente local en 2016 con ocupación empleadxs, con edades entre 26-29 años y 1 hijx, quienes usaban condón y no especifican MPF posterior, además se desconocen abortos, cesáreas, ILE previas, menarca, IVSA. Acudieron con 7 SDG y recibieron terapia dual, se desconocen complicaciones en el procedimiento. Es de los grupos grandes',
        'características de minorías':'Máximo primaria o incluso sin acceso a la educación. Mantienen el mismo método anticonceptivo antes y después del ILE. Tienen algún seguro (IMSS, ISSTE, etc). Casadas. No firmaron o se desconoce si firmaron el consentimiento informado. IVSA  < 8 años. Hay quienes han tenido 2 o más gestas',
    },
    'B': {
        'nombre':'Estudiantes de nivel media-superior y superior con decisión de Anticonceptivos Reversibles de Larga Duración (ARLD) post-ILE',
        'conclusión general':'Gente foránea en 2018, se desconoce ocupación o es estudiante, con edades de 19-21 años y sin hijxs, menarca 8-12, IVSA 3 años después de menarca, ILE 4 años después de IVSA. Recibieron 2 citas previas, consejería, terapia dual y se prescribe analgésico.  Se desconocen complicaciones en el procedimiento. El grupo más grande',
        'características de minorías':'Grado de estudio preparatoria o licenciatura. Cambian método anticonceptivo con predominio de implante subdérmico. No han tenido ILE previos. No firmaron o se desconoce si firmaron el consentimiento informado',
    },
    'C': {
        'nombre':'Madres con gesta avanzada',
        'conclusión general':'Trabajadorx del hogar no remuneradx con preparatoria, de 22-29 años y unión libre con 1 hijx menarca 8-11, IVSA 6 años después, ILE 7 años después. No cambian el condón antes ni después del procedimiento. Acuden con 10 semanas o más de gestación sin citas o 2 citas previas. Presencia de dolor después del procedimiento y se prescribe analgésicos. Es de los grupos pequeños',
        'características de minorías':'Servicio de cirugía ambulatoria. Procedimiento AMEU',
    },
    'D': {
        'nombre':'Trabajadoras del hogar no remuneradas sin hijos',
        'conclusión general':'Trabajadorx del hogar no remuneradx con secundaria sin hijxs, de 22-25 años. No ocupan MPF previo. Menarca a los 13 años, IVSA 4 años después e ILE 8 años después. Una cita previa, recibieron terapia dual, se desconoce si hubo complicaciones. ',
        'características de minorías':'',
    },
    'E': {
        'nombre':'Madres maduras foráneas con menarca temprana',
        'conclusión general':'Trabajadorx del hogar no remuneradx con secundaria y 2 hijxs, poca gente local, 22-35. No ocupan MPF. Menarca de 8-11 años, IVSA 5 años después, ILE 8 años después. Con una cita previa y 7 semanas de gestación, recibe terapia dual y sin dolor después del procedimiento por lo que no se prescribe analgésico. Es el grupo más pequeño',
        'características de minorías':'',
    },
    'F': {
        'nombre':'Jóvenes de 22-25 desempleadas con decisión de ILE en año de pandemia',
        'conclusión general':'Alta frecuencia en 2020, personas de diferentes niveles educativos (pocos sin acceso a la educación) con edades entre 22-25 sin hijxs o se desconoce el número de hijxs, sin MPF previo. Menarca a los 12 años, IVSA 3 años después, ILE 6 años después. Recibieron consejería y sin dolor después del proced por lo que no se prescribe analgésico y no se complica el procedimiento. Grupo grande',
        'características de minorías':'Personas separadas. Personas desempleadas. Personas que respondieron no tener religión',
    },
    'G': {
        'nombre':'Atención directa en servicio Gineco-Obstetricia (GO)',
        'conclusión general':'No se conoce la fecha de ILE, del total poca gente de EdoMéx, estudiante o empleadx entre edades 19-29 años y sin hijxs. Menarca a los 12 años, IVSA 3 años después, ILE 4 años después, sin MPF previo, acude acompañadx directamente a ser atendidx por especialidad de gineco-obstetricia con 6-8 semanas de gestación, no hay dolor después del proced por lo que no se prescribe analgésico. Grupo pequeño',
        'características de minorías':'',
    },
    'H': {
        'nombre':'1er Interrupción Legal del Embarazo (ILE) de personas con educación superior',
        'conclusión general':'Gente mexiquense empleadx en 2017 de 22-25 años sin hijxs. Menarca 8-14 años, IVSA 3 años después, ILE 4 años después., sin MPF previo y después implante. Recibieron consejería y terapia dual y no se complica el procedimiento. Grupo grande',
        'características de minorías':'Sin seguro. Tienen licenciatura o posgrado. Sin abortos previos',
    },
    'I': {
        'nombre':'Madres maduras con pareja en unión libre',
        'conclusión general':'Trabajadorx del hogar no remuneradx de 30-35 años en unión libre con 1 o más hijxs con secundaria acompañadxs por pareja. Menarca 12 años, IVSA 3 años después, ILE 10 años después. Es referidx de otra unidad, con 3 o más citas previas hubo dolor por lo que se prescribe analgésico. Grupo pequeño',
        'características de minorías':'Han tenido abortos y/o cesáreas',
    },
    'J': {
        'nombre':'Jóvenes de preparatoria con decisión de ILE en su primer gesta',
        'conclusión general':'Acude en 2019. Del total, poca gente de CDMX, estudiantes  de preparatoria de 19-21 años sin hijxs. Menarca 12 años, IVSA 5 años después entonces es muy probablemente que ILE sea su primer encuentro sexual. Antes ningún MPF y después condón. No hubo dolor por lo que no se prescribe analgésico. Grupo pequeño',
        'características de minorías':'De los procedimientos que se complican, la mayoría está aquí. ',
    },
}

# %% [markdown]
# #### A tabla

# %%
resumen = DataFrame(nom).T.reset_index().rename(columns={'index':'cluster'})
resumen
# Out:
#   cluster                                             nombre  \
# 0       A  Educación restringida e Inicio de Vida Sexual ...
# 1       B  Estudiantes de nivel media-superior y superior...
# 2       C                          Madres con gesta avanzada
# 3       D    Trabajadoras del hogar no remuneradas sin hijos
# 4       E       Madres maduras foráneas con menarca temprana
# 5       F  Jóvenes de 22-25 desempleadas con decisión de ...
# 6       G  Atención directa en servicio Gineco-Obstetrici...
# 7       H  1er Interrupción Legal del Embarazo (ILE) de p...
# 8       I           Madres maduras con pareja en unión libre
# 9       J  Jóvenes de preparatoria con decisión de ILE en...
#
#                                   conclusión general  \
# 0  Gente local en 2016 con ocupación empleadxs, c...
# 1  Gente foránea en 2018, se desconoce ocupación ...
# 2  Trabajadorx del hogar no remuneradx con prepar...
# 3  Trabajadorx del hogar no remuneradx con secund...
# ...

# %% [markdown]
# ## Resumen

# %%
resumen
# Out:
#   cluster                                             nombre  \
# 0       A  Educación restringida e Inicio de Vida Sexual ...
# 1       B  Estudiantes de nivel media-superior y superior...
# 2       C                          Madres con gesta avanzada
# 3       D    Trabajadoras del hogar no remuneradas sin hijos
# 4       E       Madres maduras foráneas con menarca temprana
# 5       F  Jóvenes de 22-25 desempleadas con decisión de ...
# 6       G  Atención directa en servicio Gineco-Obstetrici...
# 7       H  1er Interrupción Legal del Embarazo (ILE) de p...
# 8       I           Madres maduras con pareja en unión libre
# 9       J  Jóvenes de preparatoria con decisión de ILE en...
#
#                                   conclusión general  \
# 0  Gente local en 2016 con ocupación empleadxs, c...
# 1  Gente foránea en 2018, se desconoce ocupación ...
# 2  Trabajadorx del hogar no remuneradx con prepar...
# 3  Trabajadorx del hogar no remuneradx con secund...
# ...

# %%
ile.export_csv(resumen, name_suffix='resumen', index=False)
# Out:
# Archivo: interrupcion_embarazo_clean_cluster_resumen.csv fue exportado exitosamente en: /Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data
