# %% [markdown]
# # Consumo de agua CDMX

# %% [markdown]
# ## Parameters

# %%
RESOURCE_ID = '2263bf74-c0ed-4e7c-bb9c-73f0624ac1a9'
BASE_DIR = '/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data'
FILE_NAME = 'consumo-agua.csv'

# %% [markdown]
# ## Import API

# %%
# _ = ca.api_export(resource_id=RESOURCE_ID, export_kwargs={'file_name':FILE_NAME, 'index':False})
# Out:
# Archivo: consumo_agua.csv fue exportado exitosamente en: /Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data

# %%
from mariachis.models import BaseClass

class ConsumoAgua(BaseClass):
    def __init__(self, base_dir: str) -> None:
        super().__init__(base_dir)

    def 

ca = ConsumoAgua(BASE_DIR)
print(ca)
# Out:
# Directorio:	/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data

# %%
df = ca.get_csv(FILE_NAME)
df
# Out:
#           id                  geo_point_2d  \
# 0          0  19.4552601937,-99.1126617526
# 1          1  19.4552601937,-99.1126617526
# 2          2  19.4557195871,-99.1135822797
# 3          3  19.4596467168,-99.1044693641
# 4          4  19.4741606185,-99.1467497317
# ...      ...                           ...
# 71097  71097  19.4485642979,-99.1399395353
# 71098  71098  19.4493393649,-99.1457191092
# 71099  71099  19.4483923147,-99.1459300721
# 71100  71100  19.4475868325,-99.1425094385
# 71101  71101  19.4474017534,-99.1397251034
#
#                                                geo_shape  consumo_total_mixto  \
# 0      {"type": "MultiPolygon", "coordinates": [[[[-9...               159.72
# 1      {"type": "MultiPolygon", "coordinates": [[[[-9...                 0.00
# 2      {"type": "MultiPolygon", "coordinates": [[[[-9...                 0.00
# 3      {"type": "MultiPolygon", "coordinates": [[[[-9...                 0.00
# ...

# %%
(df['anio'].astype(str)+'-'+df['bimestre'].astype(str)).value_counts(1)
# Out:
# 2019-2    0.336728
# 2019-3    0.335040
# 2019-1    0.328233
# dtype: float64

# %%
df.shape
# Out:
# (32000, 19)
