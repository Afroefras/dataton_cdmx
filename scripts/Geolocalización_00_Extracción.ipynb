# %% [markdown]
# # Extracción

# %% [markdown]
# ## Parámetros

# %%
BASE_DIR = '/Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data' # Mac
# BASE_DIR = r'D:\Users\efras\Documents\EF\Contests\Datathon_CDMX\data' # Windows
FILE_NAME = 'municipios'

# %% [markdown]
# ## Importar

# %% [markdown]
# ### Clases

# %%
from mariachis.geoloc import GeoLoc

geo = GeoLoc(BASE_DIR, FILE_NAME)

# %% [markdown]
# ### Municipios desde URL

# %%
df = geo.get_data()
df.sample()
# Out:
# Archivo: municipios.csv fue exportado exitosamente en: /Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data
#        country_code postal_code place_name state_name state_code  \
# 125005           MX       86947  El Faisán    Tabasco         27
#
#        province_name province_code community_name community_code      lat  \
# 125005      Balancán           001                                17.6544
#
#              lon accuracy
# 125005  -91.5564        4

# %% [markdown]
# ## Alcaldía o municipio

# %% [markdown]
# ### Transformación

# %%
gdf = geo.wrangling_geo(df, group_by='province_name')
gdf.sample()
# Out:
# Archivo: municipios_geoloc.csv fue exportado exitosamente en: /Users/efraflores/Desktop/EF/Contests/Datathon_CDMX/data
#           province_name                                           geometry  \
# 1710  Santiago Camotlán  POLYGON ((-96.247 17.507, -96.247 17.507, -96....
#
#      country_code state_name state_code province_code      lat       lon  \
# 1710           MX     Oaxaca         20           457  17.4454  -96.1851
#
#                                               geo_shape      area  \
# 1710  {'type': 'Point', 'coordinates': (-96.1851, 17...  0.033731
#
#                                                boundary  \
# 1710  LINESTRING (-96.247 17.507, -96.247 17.507, -9...
#
#                     centroid  \
# 1710  POINT (-96.184 17.541)
#
#                                             convex_hull  centroid_lat  \
# 1710  POLYGON ((-96.185 17.395, -96.190 17.396, -96....    -96.183831
#
#       centroid_lon
# 1710     17.541142

# %% [markdown]
# ### Mapa

# %%
gdf.plot('area')
# Out:
# <AxesSubplot:>
